# %% [markdown]
# <a href="https://colab.research.google.com/github/kevin67883/Progralll-Semi-2026/blob/main/miPrimerProyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
saludo = "Hola chicos de progra III"
print(saludo, "Primera letra saludo", saludo[0:4])

num1 = 5.25
print(num1)

booleano = True
print(booleano)
# Out:
# Hola chicos de progra III Primera letra saludo Hola
# 5.25
# True

# %%
print("Sumar dos numeros: ")
num1 = input("Num1: ")
num2 = input("Num2: ")
respuesta = float(num1) + float(num2)

print(type(num1), type(num2), type(respuesta))

print ("Respuesta: ", respuesta)

respuesta ="Suma Completa"
print (respuesta, type(respuesta))
# Out:
# Sumar dos numeros:
# Num1: 6
# Num2: 5
# <class 'str'> <class 'str'> <class 'float'>
# Respuesta:  11.0
# Suma Completa <class 'str'>

# %%
print ("Multiplicar dos numeros")
num1 = input("Num1: ")
num2 = input("Num2: ")
respuesta = float(num1) * float(num2)
print("respuesta: ", respuesta)
# Out:
# Multiplicar dos numeros
# Num1: 4
# Num2: 5
# respuesta:  20.0

# %%
print ("Dividir dos numeros: ")
num1 = input("Num1: ")
num2 = input("Num2: ")
respuesta = float(num1) / float(num2)
print("Respuesta: ", respuesta)
# Out:
# Dividir dos numeros:
# Num1: 5
# Num2: 6
# Respuesta:  0.8333333333333334

# %%
saludo = "Hola chicos de progra III"
print( "Primera letra saludo", saludo[0:4])
print("Rango en una cadena", saludo[0:4])
print("Ultimo Elemento", saludo[-1])
print("Ultimo Elemento", saludo[len(saludo) -1])
print( "Valor en medio, sin espedificar un valor", saludo[5:])
print( "Sin valor al inicio", saludo[:4])
print( "Contar del final", saludo[5:-1])
# Out:
# Primera letra saludo Hola
# Rango en una cadena Hola
# Ultimo Elemento I
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3850/3610757479.py in <cell line: 0>()
#       3 print("Rango en una cadena", saludo[0:4])
#       4 print("Ultimo Elemento", saludo[-1])
# ----> 5 print("Ultimo Elemento", saludo(len(saludo) -1))
#       6
#       7
#
# TypeError: 'str' object is not callable
